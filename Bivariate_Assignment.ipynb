# %%
import pandas as pd
dataset = pd.read_csv('Placement_Data_Full_Class.csv')
dataset
# Out:
# C:\Users\rajes\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\rajes\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qual = quanQual(dataset)

# %%
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3      4.0      M   56.0  Central   52.0  Central   Science     52.00
# 5      6.0      M   55.0   Others   49.8   Others   Science     67.25
# 6      7.0      F   46.0   Others   49.2   Others  Commerce     79.00
# 7      NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 8      NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 200  199.0      F   67.0  Central   70.0  Central  Commerce     65.00
# 203  202.0      M   54.2  Central   63.0   Others   Science     58.00
# 208  207.0      M   41.0  Central   42.0  Central   Science     60.00
# 210  209.0      F   43.0  Central   60.0   Others   Science     65.00
# 216  215.0      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#Question 1 
#checked the dataset for null values using isnull function it retured 2 for all columns then displayed the rows
#having complete null values using how= all function it displayed two rows so deleted that two row completely.
#these two rows does not add any values to the dataset
dataset = dataset.dropna(how='all')

# %%
#validated dataset after droping null values
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#After dropping complete null rows we got 67 null for salary column. For not placed students the salary was null, by
#by default not placed students will not get any salary so filled those columns with 0 as income
dataset.fillna(0,inplace = True)
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_24160\149717894.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.fillna(0,inplace = True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#2.Filtered the dataset having status as not placed after that selected those columns using dataset[]
#then applied shape function to count the number of rows.
dataset[dataset.status=='Not Placed'].shape[0]
# Out:
# 67

# %%
dataset_not_placed = dataset[dataset.status=='Not Placed']

# %%
#3 to find the reason for non placement trying to understand the coorelation between all columns.  
#finding correlation for the quantitative columns for only non placed students.
#highly correlated values are ssc_p,hsc_p with mba_p so for those who are not placed the percentage of ssc hsc and mba
#are the reasons. 
dataset_not_placed[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p  salary
# sl_no     1.000000 -0.045063  0.177684 -0.052066  0.130630  0.229686     NaN
# ssc_p    -0.045063  1.000000  0.340030  0.291363  0.012215  0.434229     NaN
# hsc_p     0.177684  0.340030  1.000000  0.342820  0.036848  0.441932     NaN
# degree_p -0.052066  0.291363  0.342820  1.000000  0.109484  0.238300     NaN
# etest_p   0.130630  0.012215  0.036848  0.109484  1.000000  0.017030     NaN
# mba_p     0.229686  0.434229  0.441932  0.238300  0.017030  1.000000     NaN
# salary         NaN       NaN       NaN       NaN       NaN       NaN     NaN

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset[quan])
#4 Correlation between salary and mba_p is very less because the value is 0.13 and the graph is also non linear

# %%
# !pip3 install seaborn==0.9.0

# %%
#5 first filtered only the placed students so that 0 does not comes into calculation
#filtered the minimum salary after that selected the specialization of that student
dataset[dataset.status=='Placed'].min().specialisation
# Out:
# 'Mkt&Fin'

# %%
#6. How many of them getting above 500000 salary?
#filtered the dataset with salary greater than 50000 after that counted the rows to get number of students 
#get above 500000 salary. 
dataset[dataset.salary>50000].count().sl_no
# Out:
# 148

# %%
#7. Test the Analysis of Variance between etest_p and mba_p at signifance
# level 5%.(Make decision using Hypothesis Testing)
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
#Done analysis of the variance using stats method 
#P value is 0.000000000000000000004672547689133573
#P value is far lesser  than 0.05 so there is   significant diff between etest_p and mba_p
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#8. Test the similarity between the degree_t(Sci&Tech) and specialisa
# tion(Mkt&HR) with respect to salary at significance level of 5%.(Make
#  decision using Hypothesis Testing)

# filter out the dataset with students studying in sci and tec and Market and HR
#applied analysis of variance on top of the new dataset wtih salary as the decision factor. 
#p value is 0.007 which is less than 0.05 accept level mentioned so accept alternate hypothesis
#there is  significant difference between students salary who studieed in  sci and tech degree 
               #versus students salary who studied in market and hr department
    
dataset_sci = dataset[dataset.degree_t=='Sci&Tech']
dataset_hr = dataset[dataset.specialisation=='Mkt&HR']
stats.f_oneway(dataset_sci['salary'],dataset_hr['salary'])
# Out:
# F_onewayResult(statistic=7.247086057003169, pvalue=0.00789796994347111)

# %%
# 9)Convert the normal distribution to standard normal distribution for
#  salary column

#I tried to see standard distribution for whole dataset but was getting two curves that is one for placed
#and one for not placed. the salary for not placed is 0 so there is no value to see the standard distribution for 
#not placed students. so I filtered out only the placed students to see the standard deviation. 

def stndgraph(dataset):
    import seaborn as sns
    
    mean = dataset.mean()
    std = dataset.std()
    
    values = [i  for i in dataset]
    z_score = [((j-mean)/std)for j in values]
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
dataset_placed = dataset[dataset.status=='Placed']
stndgraph(dataset_placed['salary'])

# %%
#10. What is the probability Density Function of the salary range from
#  700000 to 900000
#applied matplot lib to create a distplot for the probability function using mean and standard deviation. 
#probability of getting salary from 7 lakh to 9 lakh is very minimal less than 1 percent
def get_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    sample = dataset
    sample_mean = sample.mean()
    sample_std = sample.std()
    print('Mean=',(sample_mean))
    print('Standard deviation=',(sample_std))
    dist = norm(sample_mean,sample_std)
    values = [value for value in range(startrange,endrange)]
    probabilities = [dist.pdf(value)for value in values]
    prob = sum(probabilities)
    print('probability is ',prob)
    return prob

# %%
get_probability(dataset['salary'],700000,900000)
# Out:
# Mean= 198702.32558139536
# Standard deviation= 154780.92671560097
# probability is  0.0005973310593974868
# 0.0005973310593974868

# %%
# 11)Test the similarity between the degree_t(Sci&Tech)with respect to
#  etest_p and mba_p at significance level of 5%.(Make decision using Hy
# pothesis Testing)
# filtered our the science and Tech students dataset and applied hypothesis using stats function. 
#p value is more than 0.05 value which is way higher than that so accept null hypothesis and reject alternate hypothesis
#there is a no significant difference between sci&tech students e test and mba percentage
stats.f_oneway(dataset_sci['etest_p'],dataset_sci['mba_p'])
# Out:
# F_onewayResult(statistic=20.53902604077106, pvalue=1.4289217003775155e-05)

# %%
# Which parameter is highly correlated with salary?
#checked the correlation factor for all quantitative columns.
#ssc_p is highly correlated with salary since the correlation value is 53 percent higher than other values. 
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# plot any useful graph and explain it.
sns.distplot(dataset_placed['ssc_p'],color='Green')
sns.distplot(dataset_placed['hsc_p'],color='Blue')
sns.distplot(dataset_placed['degree_p'],color='Red')
sns.distplot(dataset_placed['etest_p'],color='Yellow')
sns.distplot(dataset_placed['mba_p'],color='Orange')

#For graph trying to validate the percentage level at each stage for the placed students.
#Conclusion after seeing the plot graph is 
#students who were constantly increasing in their percentage from ssc to degree got placed
#these students got low only in the e test percentage. other than that they were constantly showing good performance in their
#main exams
# Out:
# <AxesSubplot:xlabel='mba_p'>
